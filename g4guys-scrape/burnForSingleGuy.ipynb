# %%
import requests 
from bs4 import BeautifulSoup

url = 'http://www.g4guys.com/thread-157583-1-1.html'
req = requests.get(url)
soup = BeautifulSoup(req.text, 'html.parser')
# print(soup.prettify())

# %%
raw_story = soup.find_all('td', id="postmessage_9133271")[0]
# raw_story

# %%
# brs = raw_story.find_all('br')
# for br in brs:
#     print(br.string)

# %%
for string in raw_story.stripped_strings:
    formatted_string = '\t' + string + '\n\n'
    print(formatted_string)
# Out:
# 	แก้ไขครั้งสุดท้ายโดย laser เมื่อ 2022-1-18 13:21
#
#
# 	สวัสดีครับ เนื่องจากมีคนรออ่านเรื่องใหม่ เร่งอยากให้เขียนเรื่องต่อไป เลยถือโอกาสบอกทุกท่านผ่านกระทู้นี้เลยว่า ยูสเซอร์ผม มีอายุนานแล้วครับ จริงๆ เป็นของคนรู้จักคนนึงที่เลิกเล่นแล้วยกให้ผมมาหลายปีแล้ว  ดังนั้น เรื่องแรกๆ ไม่กี่เรื่อง ที่ลงไว้หลายปีก่อนเป็นเรื่องที่เอามาจากที่อื่นบ้าง ส่วนเรื่องกลางๆ ถึงหลังๆ ที่ผมเขียนเองจะเป็นประสบการณ์ชีวิต เน้นวัยทำงานใหม่ๆ กับวัยเรียน มันมีเยอะก็จริงแต่ก็กระจุกอยู่แค่ช่วงอายุขณะนั้นครับ พอโตมากขึ้นก็ไม่ค่อยเจออะไรตื่นเต้นแล้ว เพราะต้องทำงานเป็นหลักเรื่องเสียวเป็นรอง ปากท้องสำคัญกว่า 555
#
#
# 	เอาจริงถ้าเขียนบ่อยๆ ก็คงหมดเรื่องเล่าในอีกไม่นานนี้ ก็ได้คำชวนจากบางท่านว่า เล่ามาเถอะ ถ้าเล่าหมดแล้วก็ปล่อยให้หมดไปเลย แล้วค่อยเขียนเรื่องแต่งหรือเขียนนิยายเต็มตัวไปเลยก็ได้  ก็จะเก็บไปพิจารณาครับ  คิดว่าถ้าเล่าประสบการณ์ชีวิตให้หมด คงจะหมดเรื่องเล่าภายในปีสองปีนี้ครับ จากนั้นจะลองเขียนเรื่องแต่งที่เป็นตัวละครสมมุติดูมั่ง
#
#
# ...
