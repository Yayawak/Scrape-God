# %%
import requests 
from bs4 import BeautifulSoup

urlSaraban = 'https://phyblas.hinaboshi.com/saraban/'
req = requests.get(urlSaraban)
soup = BeautifulSoup(req.text, 'html.parser')
# soup

# %%
pre_docs = soup.find(id='lak')

docs = list(pre_docs.stripped_strings)[2:]
# docs
for pre_doc in pre_docs:
    doc_name = pre_doc.string
    link = pre_doc.find('a')
    print(link)
# Out:
# -1
# <a class="twitter-share-button" data-lang="th" href="https://twitter.com/share">ทวีต</a>
# None
# None
# -1
# None
# -1
# <a href="/saraban/manim">manim</a>
# -1
# <a href="/saraban/caligula">caligula</a>
# -1
# <a href="/saraban/tangdaen">บันทึกในประเทศอื่นๆ</a>
# -1
# <a href="/saraban/pokemon">โปเกมอน</a>
# -1
# <a href="/saraban/mongol">mongol</a>
# -1
# <a href="/saraban/maya">maya</a>
# -1
# <a href="/saraban/zhongguo">บันทึกในจีน</a>
# -1
# <a href="/saraban/pythomon">python module</a>
# -1
# <a href="/saraban/hoenggong">บันทึกในฮ่องกงและมาเก๊า</a>
# -1
# <a href="/saraban/javascript">javascript</a>
# -1
# <a href="/saraban/opencvpython">opencv-python</a>
# -1
# <a href="/saraban/phasasat">ภาษาศาสตร์</a>
# -1
# <a href="/saraban/khwamnachapen">ความน่าจะเป็นเบื้องต้นสำหรับเขียนโปรแกรม</a>
# -1
# <a href="/saraban/taiwan">บันทึกในไต้หวัน</a>
# -1
# <a href="/saraban/beijing">บันทึกในปักกิ่ง</a>
# -1
# <a href="/saraban/numpy_matplotlib">numpy และ matplotlib</a>
# -1
# ...
