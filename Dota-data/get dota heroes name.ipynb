# %%
# from bs4 import BeautifulSoup 
import requests

url = 'https://api.opendota.com/api/heroes/'
req = requests.get(url)
# print(web_data.text)
# soup = BeautifulSoup(web_data.text , "html.parser")
# print(soup.prettify())

# %% [markdown]
# ## Beautiful soup use with html & xml not Json object

# %%
data = req.json()
print(data[0])
# Out:
# {'id': 1, 'name': 'npc_dota_hero_antimage', 'localized_name': 'Anti-Mage', 'primary_attr': 'agi', 'attack_type': 'Melee', 'roles': ['Carry', 'Escape', 'Nuker'], 'legs': 2}

# %%
print(len(data)) # num of heroes
# Out:
# 123

# %%
heroes = [ hero for hero in data]
# heroes

# %%
names = [ hero['localized_name'] for hero in heroes]
# names
