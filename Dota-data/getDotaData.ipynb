# %%
import requests
import json

# %%
url = 'https://raw.githubusercontent.com/joshuaduffy/dota2api/master/dota2api/ref/heroes.json'
req = requests.get(url)
data = req.json()
print(data['heroes'][0])
# Out:
# {'localized_name': 'Anti-Mage', 'url_full_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_full.png', 'name': 'npc_dota_hero_antimage', 'url_small_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_sb.png', 'url_large_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_lg.png', 'url_vertical_portrait': 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_vert.jpg', 'id': 1}

# %%
from skimage import io
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams['figure.autolayout'] = True

# im1 = io.imread(data['heroes'][0]['url_small_portrait'])
f = 'http://cdn.dota2.com/apps/dota2/images/heroes/antimage_lg.png'
sklearnIconImg = s = 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Scik\
it_learn_logo_small.svg/1200px-Scikit_learn_logo_small.svg.png'
im1 = io.imread(s)
plt.imshow(im1)
plt.axis('off')
plt.show()

# %% [markdown]
# ## bug is: this url image ( dota file )  is not secure so it's can't retrive data
